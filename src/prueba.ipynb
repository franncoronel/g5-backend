# %%
import os
import pandas as pd

TITULOS = '../data/title.basics.tsv'

def read_tsv_chunks(file_path: str):
    return pd.read_csv(file_path, sep='\t', chunksize=10000)

# %%
titulos_iterable = read_tsv_chunks(TITULOS)

ultimo_chunk = None
for chunk in titulos_iterable:
    ultimo_chunk = chunk

ultimo_chunk.tail(15)
# Out:
#              tconst  titleType                primaryTitle  \
# 11875176  tt9916826  tvEpisode               Episode #3.10
# 11875177  tt9916830  tvEpisode                Episode #2.6
# 11875178  tt9916832  tvEpisode               Episode #3.11
# 11875179  tt9916834  tvEpisode               Episode #3.12
# 11875180  tt9916836  tvEpisode               Episode #3.14
# 11875181  tt9916838  tvEpisode               Episode #3.13
# 11875182  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 11875183  tt9916842  tvEpisode               Episode #3.16
# 11875184  tt9916844  tvEpisode               Episode #3.15
# 11875185  tt9916846  tvEpisode               Episode #3.18
# 11875186  tt9916848  tvEpisode               Episode #3.17
# 11875187  tt9916850  tvEpisode               Episode #3.19
# 11875188  tt9916852  tvEpisode               Episode #3.20
# 11875189  tt9916856      short                    The Wind
# 11875190  tt9916880  tvEpisode   Horrid Henry Knows It All
#
# ...

# %%
df_nombres = read_tsv_chunks('../data/name.basics.tsv')
df_nombres.tail(10)
# Out:
#              nconst         primaryName birthYear deathYear  \
# 14677622  nm9993709           Lu Bevins        \N        \N
# 14677623  nm9993710   Nestor Rudnytskyy        \N        \N
# 14677624  nm9993711       David Gluzman        \N        \N
# 14677625  nm9993712     Corny O'Connell        \N        \N
# 14677626  nm9993713       Sambit Mishra        \N        \N
# 14677627  nm9993714   Romeo del Rosario        \N        \N
# 14677628  nm9993716       Essias Loberg        \N        \N
# 14677629  nm9993717  Harikrishnan Rajan        \N        \N
# 14677630  nm9993718         Aayush Nair        \N        \N
# 14677631  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 14677622             producer,writer,director
# 14677623                                   \N
# 14677624                                   \N
# 14677625                                   \N
# 14677626                      writer,producer
# ...

# %%
df_crew = read_tsv_chunks('../data/crew.basics.tsv')
df_crew.tail(10)

# %%
df_episodios = read_tsv_chunks('../data/episode.basics.tsv')
df_episodios.tail(10)

# %%
df_criticas = read_tsv_chunks('../data/review.basics.tsv')
df_criticas.tail(10)

# %%
def direccionArchivo():
    absFilePath=os.path.abspath(__file__)
    path,filename=os.path.split(absFilePath)

    return path

def crearData():
    path=direccionArchivo()
    return pd.read_csv(path+"./mundial.csv")
